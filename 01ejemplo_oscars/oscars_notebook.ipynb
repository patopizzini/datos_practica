# %%
## IMPORTACIÓN GENERAL DE LIBRERIAS Y VISUALIZACIÓN DE DATOS (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as DT
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
plt.style.use('default') 
sns.set(style="whitegrid") 
plt.rcParams['figure.figsize'] = (15, 10)

# %%
covid = pd.read_csv('csv/covid.csv', encoding="utf-16", sep=',')

# %%
covid.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0          672064    M  52.0            Años              Argentina
# 1          717629    F  46.0            Años              Argentina
# 2          717926    F  41.0            Años              Argentina
# 3          718029    F  52.0            Años              Argentina
# 4          718055    F  34.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                Buenos Aires               Florencio Varela
# 1                Buenos Aires                      Pergamino
# 2                        CABA                      COMUNA 12
# 3                Buenos Aires                       La Plata
# 4                        CABA                SIN ESPECIFICAR
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires            2020-05-29            NaN  ...
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172437 entries, 0 to 172436
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   id_evento_caso                    172437 non-null  int64
#  1   sexo                              172437 non-null  object
#  2   edad                              172131 non-null  float64
#  3   edad_años_meses                   172437 non-null  object
#  4   residencia_pais_nombre            172437 non-null  object
#  5   residencia_provincia_nombre       172437 non-null  object
#  6   residencia_departamento_nombre    172437 non-null  object
#  7   carga_provincia_nombre            172437 non-null  object
#  8   fecha_inicio_sintomas             115207 non-null  object
#  9   fecha_apertura                    172436 non-null  object
#  10  sepi_apertura                     172437 non-null  int64
# ...

# %%
covid.isnull().sum()
# Out:
# id_evento_caso                           0
# sexo                                     0
# edad                                   306
# edad_años_meses                          0
# residencia_pais_nombre                   0
# residencia_provincia_nombre              0
# residencia_departamento_nombre           0
# carga_provincia_nombre                   0
# fecha_inicio_sintomas                57230
# fecha_apertura                           1
# sepi_apertura                            0
# fecha_internacion                   125107
# cuidado_intensivo                        0
# fecha_cui_intensivo                 165386
# fallecido                                0
# fecha_fallecimiento                 170379
# asistencia_respiratoria_mecanica         0
# carga_provincia_id                       0
# origen_financiamiento                    0
# Clasificacion                            0
# clasificacion_resumen                    0
# residencia_provincia_id                  0
# ...

# %%
muertos = covid[covid['fallecido']=="SI"]
muertos.clasificacion_resumen.value_counts()
# Out:
# Descartado    1320
# Confirmado     648
# Sospechoso      90
# Name: clasificacion_resumen, dtype: int64

# %%
muertos.groupby('residencia_provincia_nombre')[['edad_años_meses']].count()
# Out:
#                              edad_años_meses
# residencia_provincia_nombre
# Buenos Aires                            1024
# CABA                                     568
# Chaco                                    122
# Chubut                                    12
# Corrientes                                 5
# Córdoba                                   53
# Entre Ríos                                66
# La Pampa                                  11
# La Rioja                                  18
# Mendoza                                   47
# Misiones                                  12
# Neuquén                                   13
# Río Negro                                 33
# SIN ESPECIFICAR                            4
# Salta                                      8
# San Luis                                   1
# Santa Cruz                                 4
# Santa Fe                                  33
# Santiago del Estero                        7
# ...

# %%
covid.clasificacion_resumen.value_counts()
# Out:
# Descartado        138672
# Confirmado         22007
# Sospechoso         11755
# Sin Clasificar         3
# Name: clasificacion_resumen, dtype: int64

# %%
caba = covid[covid['residencia_provincia_nombre']=="CABA" & covid[covid['clasificacion_resumen']=='Confirmado']

caba.residencia_departamento_nombre.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/pato/.local/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-2fd48c875b7b> in <module>()
# ----> 1 caba = (covid[covid['residencia_provincia_nombre']=="CABA"] & covid[covid['clasificacion_resumen']=='Confirmado'])
#       2
#       3 caba.residencia_departamento_nombre.value_counts()
#
# /home/pato/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     765
# ...
